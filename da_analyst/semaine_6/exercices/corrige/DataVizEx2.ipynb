# %% [markdown]
# # Exercice n°2 : Visualisation de relations continues

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %%time
df = pd.read_csv("./data/sales_predictions.csv")
print('dataset loaded')
# Out:
# dataset loaded
# CPU times: user 1.04 s, sys: 229 ms, total: 1.27 s
# Wall time: 1.56 s

# %%
df.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
sns.relplot(x='date', y='item_price', data=df, kind='line')
plt.show()

# %%
sns.relplot(x="date", y="item_price", data = df.sample(100), kind="line", height=8, aspect=3)

# %%
df.date = pd.to_datetime(df.date)
print('date ok')
# Out:
# date ok

# %%
f, ax = plt.subplots(figsize=(20,6))
sns.relplot(x="date", y="item_price", data = df, kind="line", ax = ax)
plt.close(2)
# Out:
# /Users/mac/.pyenv/versions/3.7.0/lib/python3.7/site-packages/seaborn/relational.py:1651: UserWarning: relplot is a figure-level function and does not accept target axes. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)

# %%
#problème de visibilité (trop de data) --> prendre un sous-échantillon 
new_df = df.sample(n=25)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 809089 to 2257082
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            25 non-null     object
#  1   date_block_num  25 non-null     int64
#  2   shop_id         25 non-null     int64
#  3   item_id         25 non-null     int64
#  4   item_price      25 non-null     float64
#  5   item_cnt_day    25 non-null     float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
f, ax = plt.subplots(figsize=(28,6))
sns.relplot(x="date", y="item_price", data = new_df, kind="line", ax = ax)
plt.close(2)
# Out:
# /Users/mac/.pyenv/versions/3.7.0/lib/python3.7/site-packages/seaborn/relational.py:1651: UserWarning: relplot is a figure-level function and does not accept target axes. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)

# %%
new_df.date = pd.to_datetime(new_df.date)

# %%
f, ax = plt.subplots(figsize=(28,6))
sns.relplot(x="date", y="item_price", data = new_df, kind="line", ax = ax)
plt.close(2)
