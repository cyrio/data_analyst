# %% [markdown]
# ## Exercice 2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_sales_pred = pd.read_csv("../cours/csv_sample/sales_predictions.csv"); df_sales_pred
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
df_sales_pred.columns
# Out:
# Index(['date', 'date_block_num', 'shop_id', 'item_id', 'item_price',
#        'item_cnt_day'],
#       dtype='object')

# %%
df_sales_pred.index
# Out:
# RangeIndex(start=0, stop=2935849, step=1)

# %%
sns.relplot(data=df_sales_pred,x="date",y="item_price", kind='line'); plt.show()

# %%
help(sns.relplot)

# %%
df_sales_pred.sample(n=50, random_state=1)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 651498   12.07.2013               6       37    11691       149.0
# 460637   18.05.2013               4       25     4302       649.0
# 1696749  18.05.2014              16       47     1306       299.0
# 1081839  04.11.2013              10       18    11645       149.0
# 1865398  04.07.2014              18       21    19050       549.0
# 1072561  06.11.2013              10        6     7204       199.0
# 2030609  25.10.2014              21       28     3500      1039.0
# 1162583  11.12.2013              11       12     1645       949.0
# 2817755  22.08.2015              31       28    15066       399.5
# 1885236  20.08.2014              19       45     3475       399.5
# 499063   06.05.2013               4       59     7490       299.0
# 2469766  23.02.2015              25       28     7019      1199.0
# 1076250  25.11.2013              10       21    17794       149.0
# ...

# %%
sns.relplot(data=df_sales_pred,x="date",y="item_price",kind="line",size=20.6);plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_sales_pred["date"]=pd.to_datetime(df_sales_pred.date,format="%d.%m.%Y")

# %%
help(pd.to_datetime)

# %%
sns.relplot(data=df_sales_pred,x="date",y="item_price",kind="line",size=20.6);plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# may_flights = flights.query("month == 'May'")
# sns.lineplot(data=may_flights, x="year", y="passengers")
